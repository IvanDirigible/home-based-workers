# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# Step 1: Load the data into a DataFrame
data = {
    'State': [
        'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 
        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 
        'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 
        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 
        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 
        'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'
    ],
    'Percentage_Worked_From_Home_2022': [
        4.43, 8.06, 14.26, 6.75, 13.63, 16.49, 12.61, 11.64, 25.03, 11.94, 12.26, 7.99, 10.83, 12.10, 8.20, 9.28, 
        9.53, 7.95, 6.23, 12.34, 14.67, 14.64, 10.22, 13.65, 4.51, 9.93, 10.63, 8.89, 8.99, 13.13, 13.06, 9.59, 
        11.59, 12.39, 6.31, 9.81, 7.41, 14.95, 11.84, 4.85, 9.61, 8.51, 8.53, 9.69, 11.00, 14.07, 13.24, 13.96, 
        15.45, 6.87, 10.10, 7.70
    ]
}

df = pd.DataFrame(data)

# Step 2: Define state centroids (latitude, longitude)
state_centroids = {
    "Alabama": (32.806671, -86.791130), "Alaska": (61.370716, -152.404419), "Arizona": (33.729759, -111.431221),
    "Arkansas": (34.969704, -92.373123), "California": (36.116203, -119.681564), "Colorado": (39.059811, -105.311104),
    "Connecticut": (41.597782, -72.755371), "Delaware": (39.318523, -75.507141), "District of Columbia": (38.9072, -77.0369),
    "Florida": (27.766279, -81.686783), "Georgia": (33.040619, -83.643074), "Hawaii": (21.094318, -157.498337),
    "Idaho": (44.240459, -114.478828), "Illinois": (40.349457, -88.986137), "Indiana": (39.849426, -86.258278),
    "Iowa": (42.011539, -93.210526), "Kansas": (38.526600, -96.726486), "Kentucky": (37.668140, -84.670067),
    "Louisiana": (31.169546, -91.867805), "Maine": (44.693947, -69.381927), "Maryland": (39.063946, -76.802101),
    "Massachusetts": (42.230171, -71.530106), "Michigan": (43.326618, -84.536095), "Minnesota": (45.694454, -93.900192),
    "Mississippi": (32.741646, -89.678696), "Missouri": (38.456085, -92.288368), "Montana": (46.921925, -110.454353),
    "Nebraska": (41.125370, -98.268082), "Nevada": (38.313515, -117.055374), "New Hampshire": (43.452492, -71.563896),
    "New Jersey": (40.298904, -74.521011), "New Mexico": (34.840515, -106.248482), "New York": (42.165726, -74.948051),
    "North Carolina": (35.630066, -79.806419), "North Dakota": (47.528912, -99.784012), "Ohio": (40.388783, -82.764915),
    "Oklahoma": (35.565342, -96.928917), "Oregon": (44.572021, -122.070938), "Pennsylvania": (40.590752, -77.209755),
    "Puerto Rico": (18.2208, -66.5901), "Rhode Island": (41.680893, -71.511780), "South Carolina": (33.856892, -80.945007),
    "South Dakota": (44.299782, -99.438828), "Tennessee": (35.747845, -86.692345), "Texas": (31.054487, -97.563461),
    "Utah": (40.150032, -111.862434), "Vermont": (44.045876, -72.710686), "Virginia": (37.769337, -78.169968),
    "Washington": (47.400902, -121.490494), "West Virginia": (38.491226, -80.954456), "Wisconsin": (44.268543, -89.616508),
    "Wyoming": (42.755966, -107.302490)
}

# Step 3: Create the Basemap for the United States
fig, ax = plt.subplots(figsize=(12, 8))
m = Basemap(projection='merc', llcrnrlat=24.396308, urcrnrlat=49.384358, 
            llcrnrlon=-125.0, urcrnrlon=-66.93457, resolution='i', ax=ax)

# Step 4: Draw map details
m.drawcoastlines()
m.drawcountries()
m.drawstates()

# Step 5: Plot the data
scatter = None

for state, coords in state_centroids.items():
    print(f"State:{state}, coords: {x},{y}")
    (lon, lat) = coords
    # Convert lat/lon to map projection coordinates
    x, y = m(lon, lat)
    
    # Check if the state is in the DataFrame and get the percentage of workers working from home in 2022
    if state in df['State'].values:
        percentage = df[df['State'] == state]['Percentage_Worked_From_Home_2022'].values[0]
        print(f"now printing {state}, percentage:{percentage},coords: {x},{y}")
    else:
        # If the state is not in the DataFrame, set percentage to 0
        print(f"didn't find{state}")
        percentage = 0  
    
    # Use the percentage for the color and size of the marker
    scatter = m.scatter(x, y, c=percentage, s=100, cmap='coolwarm', edgecolors='black', linewidths=0.5, zorder=5)

# Step 6: Add a colorbar
if scatter:
    plt.colorbar(scatter, label='Percentage of Workers Who Work From Home (2022)')

# Step 7: Title and display the map
plt.title('Percentage of Workers Who Work From Home by State (2022)', fontsize=16)
plt.show()
# Out:
# State:Alabama, coords: 18653603.549875252,inf
# now printing Alabama, percentage:4.43,coords: 17547292.943129044,-25576187.802848842
# State:Alaska, coords: 17547292.943129044,-25576187.802848842
# now printing Alaska, percentage:8.06,coords: 20723468.33596602,inf
# State:Arizona, coords: 20723468.33596602,inf
# now printing Arizona, percentage:14.26,coords: 17649935.597242743,inf
# State:Arkansas, coords: 17649935.597242743,inf
# now printing Arkansas, percentage:6.75,coords: 17787811.12563766,inf
# State:California, coords: 17787811.12563766,inf
# now printing California, percentage:13.63,coords: 17915295.93781017,inf
# State:Colorado, coords: 17915295.93781017,inf
# now printing Colorado, percentage:16.49,coords: 18242610.059313554,inf
# State:Connecticut, coords: 18242610.059313554,inf
# now printing Connecticut, percentage:12.61,coords: 18524819.42559672,-14816150.7391658
# State:Delaware, coords: 18524819.42559672,-14816150.7391658
# now printing Delaware, percentage:11.64,coords: 18271377.50762949,-15937967.384517722
# State:District of Columbia, coords: 18271377.50762949,-15937967.384517722
# now printing District of Columbia, percentage:25.03,coords: 18225640.498354092,-16655485.49611076
# State:Florida, coords: 18225640.498354092,-16655485.49611076
# now printing Florida, percentage:11.94,coords: 16986827.18834353,-19501933.584460437
# State:Georgia, coords: 16986827.18834353,-19501933.584460437
# now printing Georgia, percentage:12.26,coords: 17573306.761578195,-21215933.551665105
# State:Hawaii, coords: 17573306.761578195,-21215933.551665105
# now printing Hawaii, percentage:7.99,coords: 16244939.323716233,inf
# State:Idaho, coords: 16244939.323716233,inf
# now printing Idaho, percentage:10.83,coords: 18818671.56238674,inf
# State:Illinois, coords: 18818671.56238674,inf
# now printing Illinois, percentage:12.1,coords: 18386012.084155295,-32918038.098817606
# State:Indiana, coords: 18386012.084155295,-32918038.098817606
# now printing Indiana, percentage:8.2,coords: 18330411.19997185,-24596830.883255575
# State:Iowa, coords: 18330411.19997185,-24596830.883255575
# now printing Iowa, percentage:9.28,coords: 18570827.08319613,inf
# State:Kansas, coords: 18570827.08319613,inf
# now printing Kansas, percentage:9.53,coords: 18183319.729201347,inf
# State:Kentucky, coords: 18183319.729201347,inf
# now printing Kentucky, percentage:7.95,coords: 18087863.377422918,-22340486.570497576
# State:Louisiana, coords: 18087863.377422918,-22340486.570497576
# now printing Louisiana, percentage:6.23,coords: 17365253.034565736,inf
# State:Maine, coords: 17365253.034565736,inf
# now printing Maine, percentage:12.34,coords: 18869097.103536353,-13656936.699240278
# State:Maryland, coords: 18869097.103536353,-13656936.699240278
# now printing Maryland, percentage:14.67,coords: 18243069.85011872,-16540121.57309653
# State:Massachusetts, coords: 18243069.85011872,-16540121.57309653
# now printing Massachusetts, percentage:14.64,coords: 18595137.840950735,-14371678.84265
# State:Michigan, coords: 18595137.840950735,-14371678.84265
# now printing Michigan, percentage:10.22,coords: 18717057.127275553,-22182092.027371727
# State:Minnesota, coords: 18717057.127275553,-22182092.027371727
# now printing Minnesota, percentage:13.65,coords: 18980348.353622295,inf
